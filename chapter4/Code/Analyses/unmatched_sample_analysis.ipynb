# %% [markdown]
# ## Unmatched sample analysis
#
# This notebook contains a short analysis on the matched sample.
#
# The datasets can be retrieved by running `data_to_analysis_unmatched.ipynb`.

# %%
# Load libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from stargazer.stargazer import Stargazer

from scipy import stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.compat import lzip

# %%
# Regression discontinuity package
from rdd import rdd

# %%
def to_float(x):
    try:
        return float(x)
    except:
        return None

# %%
pd.set_option('display.max_rows', 15)

unmatched_sample = pd.read_csv("../../Data/analysis/unmatched_sample_analysis.csv", dtype={'b1-nummer':str}).iloc[:,1:]

unmatched_sample['Vermogen'] = unmatched_sample['Vermogen_deflated'].apply(lambda x: to_float(x))
unmatched_sample['logVermogen'] = np.log(1+unmatched_sample['Vermogen_deflated'])
# Out:
# /Users/basmachielsen/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.scatterplot(data = unmatched_sample,
               x = 'margin',
               y = 'Vermogen')
# Out:
# <AxesSubplot:xlabel='margin', ylabel='Vermogen'>

# %%
sns.scatterplot(data = unmatched_sample,
               x = 'margin',
               y = 'logVermogen')
# Out:
# <AxesSubplot:xlabel='margin', ylabel='logVermogen'>

# %% [markdown]
# ## Short RDD Analysis (Preliminary)
#
# We first calculate the Imbens & Kalyanaraman (2012) optimal bandwidth, then filter the data accordingly.
#
# Then, we plot the discontinuity in actual data, then in bins.

# %%
threshold = 0 
bandwidth_opt = rdd.optimal_bandwidth(unmatched_sample['Vermogen'], unmatched_sample['margin'], cut=threshold)

# %%
data_rdd = rdd.truncated_data(unmatched_sample, 'margin', bandwidth_opt, cut=threshold)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_rdd['margin'], data_rdd['Vermogen'], facecolors='none', edgecolors='r')
plt.xlabel('x')
plt.ylabel('y')
plt.axvline(x=threshold, color='b')
plt.show()
plt.close()

# %%
data_binned = rdd.bin_data(data_rdd, 'Vermogen', 'margin', 50)

plt.figure(figsize=(8,6))
plt.scatter(data_binned['margin'], data_binned['Vermogen'],
    s = data_binned['n_obs'], facecolors='none', edgecolors='r')
plt.axvline(x=threshold, color='b')
plt.xlabel('Margin')
plt.ylabel('Wealth')
plt.show()
plt.close()

# %% [markdown]
# ## Second step
#
# We repeat this analysis using log(Vermogen).

# %%
threshold = 0 
bandwidth_opt = rdd.optimal_bandwidth(unmatched_sample['logVermogen'], unmatched_sample['margin'], cut=threshold)

# %%
data_rdd = rdd.truncated_data(unmatched_sample, 'margin', bandwidth_opt, cut=threshold)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_rdd['margin'], data_rdd['logVermogen'], facecolors='none', edgecolors='r')
plt.xlabel('x')
plt.ylabel('y')
plt.axvline(x=threshold, color='b')
plt.show()
plt.close()

# %%
data_binned = rdd.bin_data(data_rdd, 'logVermogen', 'margin', 50)

plt.figure(figsize=(8,6))
plt.scatter(data_binned['margin'], data_binned['logVermogen'],
    s = data_binned['n_obs'], facecolors='none', edgecolors='r')
plt.axvline(x=threshold, color='b')
plt.xlabel('Margin')
plt.ylabel('Wealth')
plt.show()
plt.close()

# %% [markdown]
# ## Statistical results
#
# Firstly, we just use OLS, no polynomials etc.

# %%
model = rdd.rdd(data_rdd, 'margin', 'logVermogen', cut=threshold)
print(model.fit().summary())
# Out:
# Estimation Equation:	 logVermogen ~ TREATED + margin
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:            logVermogen   R-squared:                       0.063
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     5.890
# Date:                Wed, 12 May 2021   Prob (F-statistic):            0.00334
# Time:                        20:12:54   Log-Likelihood:                -404.05
# No. Observations:                 179   AIC:                             814.1
# Df Residuals:                     176   BIC:                             823.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.8183      0.464     21.181      0.000       8.903      10.733
# TREATED        2.1583      0.701      3.081      0.002       0.776       3.541
# margin       -16.8891     10.406     -1.623      0.106     -37.426       3.647
# ==============================================================================
# Omnibus:                       85.636   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.770
# Skew:                          -1.900   Prob(JB):                     4.06e-72
# Kurtosis:                       8.445   Cond. No.                         76.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(model.fit(cov_type='hc1').summary())
# Out:
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:            logVermogen   R-squared:                       0.063
# Model:                            WLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     3.850
# Date:                Wed, 12 May 2021   Prob (F-statistic):             0.0231
# Time:                        20:13:10   Log-Likelihood:                -404.05
# No. Observations:                 179   AIC:                             814.1
# Df Residuals:                     176   BIC:                             823.7
# Df Model:                           2
# Covariance Type:                  hc1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.8183      0.622     15.776      0.000       8.598      11.038
# TREATED        2.1583      0.835      2.586      0.010       0.522       3.794
# margin       -16.8891     11.515     -1.467      0.142     -39.458       5.680
# ==============================================================================
# Omnibus:                       85.636   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              328.770
# Skew:                          -1.900   Prob(JB):                     4.06e-72
# Kurtosis:                       8.445   Cond. No.                         76.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)

# %% [markdown]
# ## Placebo tests
#
# Change the threshold to see if we still get results (we should get much smaller or no effect).
#
# Two different placebo tests:
#
# - One with full dataset
# - One with dynamic optimal bandwidth

# %%
listofmods = []

for i in [-0.1, -0.075, -0.05, -0.025, 0.0, 0.025, 0.05, 0.075]:
    
    threshold = i
    #data_placebo = rdd.truncated_data(unmatched_sample, 'margin', yname='logVermogen', cut=i)
    model = rdd.rdd(unmatched_sample, 'margin', 'logVermogen', cut=threshold).fit()
    listofmods.append(model)
    
mods = Stargazer(listofmods)

mods
# Out:
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="8"><em>Dependent variable:logVermogen</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>11.143<sup>***</sup></td><td>10.593<sup>***</sup></td><td>10.437<sup>***</sup></td><td>10.402<sup>***</sup></td><td>10.064<sup>***</sup></td><td>11.004<sup>***</sup></td><td>11.143<sup>***</sup></td><td>11.002<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(0.398)</td><td>(0.380)</td><td>(0.353)</td><td>(0.326)</td><td>(0.290)</td><td>(0.211)</td><td>(0.174)</td><td>(0.150)</td></tr><tr><td style="text-align:left">TREATED</td><td>-0.287<sup></sup></td><td>0.437<sup></sup></td><td>0.691<sup></sup></td><td>0.785<sup>*</sup></td><td>1.396<sup>***</sup></td><td>-0.182<sup></sup></td><td>-0.621<sup>*</sup></td><td>-0.304<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(0.487)</td><td>(0.486)</td><td>(0.478)</td><td>(0.463)</td><td>(0.434)</td><td>(0.377)</td><td>(0.358)</td><td>(0.347)</td></tr><tr><td style="text-align:left">margin</td><td>3.976<sup>**</sup></td><td>1.820<sup></sup></td><td>0.822<sup></sup></td><td>0.348<sup></sup></td><td>-2.036<sup></sup></td><td>3.871<sup>**</sup></td><td>5.461<sup>***</sup></td><td>4.177<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(1.753)</td><td>(1.866)</td><td>(1.967)</td><td>(1.998)</td><td>(1.956)</td><td>(1.819)</td><td>(1.716)</td><td>(1.589)</td></tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>465</td><td>465</td><td>465</td><td>465</td><td>465</td><td>465</td><td>465</td><td>465</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.018</td><td>0.019</td><td>0.022</td><td>0.024</td><td>0.039</td><td>0.018</td><td>0.024</td><td>0.019</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.014</td><td>0.015</td><td>0.018</td><td>0.019</td><td>0.035</td><td>0.014</td><td>0.020</td><td>0.015</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>2.459 (df=462)</td><td>2.458 (df=462)</td><td>2.455 (df=462)</td><td>2.453 (df=462)</td><td>2.433 (df=462)</td><td>2.460 (df=462)</td><td>2.452 (df=462)</td><td>2.458 (df=462)</td></tr><tr><td style="text-align: left">F Statistic</td><td>4.306<sup>**</sup> (df=2; 462)</td><td>4.543<sup>**</sup> (df=2; 462)</td><td>5.192<sup>***</sup> (df=2; 462)</td><td>5.593<sup>***</sup> (df=2; 462)</td><td>9.383<sup>***</sup> (df=2; 462)</td><td>4.248<sup>**</sup> (df=2; 462)</td><td>5.664<sup>***</sup> (df=2; 462)</td><td>4.521<sup>**</sup> (df=2; 462)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>

# %%
listofmods = []

for i in [-0.1, -0.075, -0.05, -0.025, 0.0, 0.025, 0.05, 0.075]:

    threshold = i
    bandwidth_opt = rdd.optimal_bandwidth(unmatched_sample['logVermogen'], unmatched_sample['margin'], cut=threshold)
    
    data_placebo = rdd.truncated_data(unmatched_sample, 'margin', yname='logVermogen', cut=threshold)
    model = rdd.rdd(data_placebo, 'margin', 'logVermogen', cut=i).fit()
    listofmods.append(model)
    
mods = Stargazer(listofmods)

mods
# Out:
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# Estimation Equation:	 logVermogen ~ TREATED + margin
# <table style="text-align:center"><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left"></td><td colspan="8"><em>Dependent variable:logVermogen</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td><td>(5)</td><td>(6)</td><td>(7)</td><td>(8)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align:left">Intercept</td><td>12.048<sup>***</sup></td><td>11.650<sup>***</sup></td><td>11.625<sup>***</sup></td><td>13.691<sup>***</sup></td><td>9.818<sup>***</sup></td><td>11.193<sup>***</sup></td><td>11.152<sup>***</sup></td><td>11.687<sup>***</sup></td></tr><tr><td style="text-align:left"></td><td>(1.757)</td><td>(0.909)</td><td>(0.952)</td><td>(1.255)</td><td>(0.464)</td><td>(0.268)</td><td>(0.170)</td><td>(0.271)</td></tr><tr><td style="text-align:left">TREATED</td><td>-1.225<sup></sup></td><td>-0.447<sup></sup></td><td>-0.474<sup></sup></td><td>-2.491<sup>*</sup></td><td>2.158<sup>***</sup></td><td>-0.408<sup></sup></td><td>-0.896<sup>**</sup></td><td>0.406<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(1.149)</td><td>(0.889)</td><td>(0.963)</td><td>(1.270)</td><td>(0.701)</td><td>(0.613)</td><td>(0.397)</td><td>(0.536)</td></tr><tr><td style="text-align:left">margin</td><td>11.059<sup></sup></td><td>10.783<sup>*</sup></td><td>15.996<sup></sup></td><td>68.190<sup>**</sup></td><td>-16.889<sup></sup></td><td>5.659<sup></sup></td><td>7.875<sup>***</sup></td><td>-9.079<sup></sup></td></tr><tr><td style="text-align:left"></td><td>(12.075)</td><td>(6.486)</td><td>(10.175)</td><td>(26.769)</td><td>(10.406)</td><td>(9.856)</td><td>(2.493)</td><td>(6.171)</td></tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Observations</td><td>108</td><td>198</td><td>146</td><td>80</td><td>179</td><td>213</td><td>414</td><td>278</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.011</td><td>0.037</td><td>0.041</td><td>0.081</td><td>0.063</td><td>0.002</td><td>0.024</td><td>0.011</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.008</td><td>0.027</td><td>0.028</td><td>0.057</td><td>0.052</td><td>-0.007</td><td>0.020</td><td>0.004</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>2.765 (df=105)</td><td>2.669 (df=195)</td><td>2.564 (df=143)</td><td>2.586 (df=77)</td><td>2.332 (df=176)</td><td>2.550 (df=210)</td><td>2.387 (df=411)</td><td>2.285 (df=275)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.571<sup></sup> (df=2; 105)</td><td>3.774<sup>**</sup> (df=2; 195)</td><td>3.059<sup>*</sup> (df=2; 143)</td><td>3.382<sup>**</sup> (df=2; 77)</td><td>5.890<sup>***</sup> (df=2; 176)</td><td>0.223<sup></sup> (df=2; 210)</td><td>5.114<sup>***</sup> (df=2; 411)</td><td>1.551<sup></sup> (df=2; 275)</td></tr><tr><td colspan="9" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td>
#  <td colspan="8" style="text-align: right">
#   <sup>*</sup>p&lt;0.1;
#   <sup>**</sup>p&lt;0.05;
#   <sup>***</sup>p&lt;0.01
#  </td></tr></table>
